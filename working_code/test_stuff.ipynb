# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

# %%
data_csv = pd.read_csv('./all_data/train_gaze_det/train_annotations.txt', header = None)
data_csv
# Out:
#                                  0       1     2     3     4     5         6   \
# 0       train/00000080/00080697.jpg       1  0.29  0.11  0.68  0.89  0.412730
# 1       train/00000039/00039036.jpg       2  0.24  0.04  0.68  0.93  0.396480
# 2       train/00000108/00108360.jpg       3  0.20  0.15  0.93  0.68  0.417860
# 3       train/00000002/00002511.jpg       4  0.29  0.20  0.36  0.80  0.520000
# 4       train/00000004/00004844.jpg       5  0.22  0.18  0.23  0.75  0.356360
# 5       train/00000097/00097718.jpg       6  0.13  0.23  0.43  0.76  0.300780
# 6       train/00000118/00118244.jpg       7  0.25  0.14  0.40  0.79  0.338180
# 7       train/00000012/00012323.jpg       8  0.03  0.13  0.85  0.84  0.790910
# 8       train/00000026/00026260.jpg       9  0.39  0.22  0.62  1.06  0.886910
# 9       train/00000057/00057055.jpg      10  0.00 -0.08  0.28  0.98  0.200290
# 10      train/00000019/00019422.jpg      11  0.09  0.32  0.22  0.57  0.227270
# ...

# %%
from GazeFollow import trainGazeNet, GazeNet

# %%
GN = GazeNet()
train = trainGazeNet(GN)
img_resize, places_mean = train.generate_batch()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-fe3b42e747d5> in <module>()
#       1 GN = GazeNet()
#       2 train = trainGazeNet(GN)
# ----> 3 img_resize, places_mean = train.generate_batch()
#
# D:\Radboud\Third Semester\Developmental_robotics\DevRob\working_code\GazeFollow.py in generate_batch(self)
#     280             img_array = ((img_array - np.min(img_array))/(np.max(img_array) - np.min(img_array))).astype(np.float32)
#     281
# --> 282             img_out, face_out, i_grid_out, i_direction = self.preprocess_image(img_array, data_pd_series)
#     283
#     284             data_batch.append(img_out)
#
# D:\Radboud\Third Semester\Developmental_robotics\DevRob\working_code\GazeFollow.py in preprocess_image(self, in_img, in_series)
#     254         eye_image_resize = np.rot90(np.fliplr(eye_image_resize))
# ...

# %%
import numpy as np
import scipy.io as sio
from scipy.misc import imresize
import matplotlib.pyplot as plt
import cv2
a = np.ones((227,227,3)) * 3
b = np.ones((227,227,3)) * 2


imsi = cv2.imread("all_data\\train_gaze_det\\data\\test\\00000000\\00000001.jpg")
print(type(imsi))
imsi = imresize(imsi, [227,227], interp='bicubic')
plt.figure()
plt.imshow(imsi)
plt.show()

print(imsi * b)

# places_mean = sio.loadmat('all_data\\train_gaze_det\\model\\model\\places_mean_resize.mat')
# imagenet_mean = sio.loadmat('all_data\\train_gaze_det\\model\\model\\places_mean_resize.mat')
# places_mean = places_mean['image_mean']
# imagenet_mean = imagenet_mean['image_mean']
# imagenet_mean - b
# Out:
# <class 'numpy.ndarray'>
# C:\Users\univeristy\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   del sys.path[0]
# [[[  58.   98.  130.]
#   [  62.   98.  128.]
#   [  66.  102.  128.]
#   ...,
#   [  22.   26.   28.]
#   [  18.   22.   24.]
#   [  18.   22.   24.]]
#
#  [[  66.  112.  144.]
#   [  58.   98.  132.]
#   [  56.   96.  126.]
#   ...,
#   [  22.   26.   28.]
#   [  18.   22.   24.]
#   [  18.   22.   24.]]
#
#  [[  84.  134.  174.]
#   [  78.  128.  166.]
#   [  68.  114.  152.]
#   ...,
#   [  20.   24.   26.]
#   [  18.   22.   24.]
#   [  18.   22.   24.]]
#
#  ...,
#  [[  94.  140.  192.]
#   [  92.  138.  190.]
#   [  94.  140.  192.]
#   ...,
#   [  20.   20.   20.]
#   [  22.   22.   22.]
#   [  20.   20.   20.]]
#
#  [[  90.  136.  188.]
#   [  90.  136.  188.]
#   [  92.  138.  190.]
#   ...,
# ...
